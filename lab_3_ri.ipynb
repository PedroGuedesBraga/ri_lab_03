# %% [markdown]
# # **Tokenização e Stemming (Lab 3) **  - Recuperação da Informação
# **Aluno: Pedro Guedes Braga **

# %%
#coding: utf-8

import pandas as pd
import nltk
import operator
import math
import matplotlib.pyplot as pyplot
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import *
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# **1 - Escolha uma estratégia de tokenização para a coleção que você está usando e justifique sua estratégia. É importante que você inclua decisões adicionais em relação ao que foi feito no Laboratório anterior (por exemplo, tratamento de maiúsculas/minúsculas e strings numéricas) (5 pts).**

# %% [markdown]
# - Tratamos um *token* como sendo qualquer sequencia de caracteres alfanuméricos que termine com espaço ou outro caractere especial.
#
# **Estratégias de tokenização usadas:**
# -  **Tratamento de maiúsculas/minúsculas (*Normalization/downcasing*):**  Para a amostra de notícias, foi identificado um grande número de palavras que apareciam de formas diferentes, por vários fatores. Por exemplo: A palavra "ser", ao aparecer iniciando um' parágrafo ou após um ponto, tinha a letra "S" maiúscula ("Ser"). Já quando aparecia em outro "local" no texto, vinha com o "s" minúsculo ("ser"). Se isso não fosse tratado, o nosso vocabulário seria gerado com redundancia (haveria duas palavras tratadas como diferentes no vocabulário: "Ser" e "ser"). Sendo assim, foi aplicado uma normalização nos tokens identificados, deixando todos em *lowercase.*
# -  **Removendo apóstrofos:** Também foi feito o uso de outra regra usada nas coleções do TREC muito efetiva, que consiste em remover apóstrofos de um token. Ex.: O'Connor -> oconnor.
# - ** Ignorando pontos em abreviações:** Também foi utilizado outra regra usada nas coleções do TREC, que consiste em remover pontos em abreviações. Ex.: I.B.M. -> ibm.

# %%
url_csv = "https://raw.githubusercontent.com/PedroGuedesBraga/ri_lab_01/master/output/results.csv"
df = pd.read_csv(url_csv)
df.dropna(inplace=True)  ##Retira campos NA (ex.: NaN, etc)
lista_de_noticias = df.text.unique() #Retorna uma lista onde cada elemento é o texto de uma noticia.
 # http://www.nltk.org/howto/portuguese_en.html - Tutorial StopWords
 # https://pythonspot.com/tokenizing-words-and-sentences-with-nltk/
palavras_a_ignorar = nltk.corpus.stopwords.words('portuguese')
palavras_a_ignorar.append('o')
palavras_a_ignorar.append('a')
palavras_a_ignorar.append('é')
palavras_a_ignorar.append('r')
  
special_chars = [',', '.', '-', '“', "”", ")", "(", ":", "%", "?", "$", "–", ""]

##Conta total de palavras
def conta_total_palavras(lista_noticias):
  total_words = 0
  for noticia in lista_noticias:
    tokens = word_tokenize(noticia)
    for token in tokens:
      if((token not in palavras_a_ignorar) and (token not in special_chars)):
        total_words += 1
  return total_words    


##Metodo auxiliar que remove apostrofos dos tokens, retornando um token em seu formato sem apostrofo
def remove_apostrophes(token):
  return token.replace("’", "").replace("'","")
  
##Metodo auxiliar que remove pontos em uma abreviacao
def remove_periods(token):
  return token.replace(".", "")

##Recebe um token(ja em lowercase) e aplica mais estratégias de tokenizacao, descritas pelas duas funcoes auxiliares acima.
def apply_tokenize_strategy(token):
  return remove_periods((remove_apostrophes(token)))


#Retorna um vocabulario, organizado da seguinte forma (em formato de dicionario): palavra(key): numero_de_ocorrencias_da_palavra(value)
def freq_palavras(lista_noticias):
  vocab = {}
  for noticia in lista_noticias:
    tokens = word_tokenize(noticia)
    for token in tokens:
      if((apply_tokenize_strategy(token.lower()) not in palavras_a_ignorar) and (apply_tokenize_strategy(token.lower()) not in special_chars)):  ## Todos os tokens passam a serem tratados em LOWERCASE
        if(apply_tokenize_strategy(token.lower()) in vocab):
          vocab[apply_tokenize_strategy(token.lower())] = vocab[apply_tokenize_strategy(token.lower())] + 1
        else:
          vocab[apply_tokenize_strategy(token.lower())] = 1 
  return vocab

#Recebe um o numero de vezes e o vocabulario
def words_more_than(times, vocab):
  count = 0
  for word in vocab:
    if(vocab[word] > times):
      count = count + 1
  return count

#Retorna numero de palavras que ocorreram apenas uma vez
def words_ocurring_once(vocab):
  count = 0
  for word in vocab:
    if(vocab[word] == 1):
      count = count + 1
  return count


vocabulario = freq_palavras(lista_de_noticias)
pd.DataFrame({'info': ['Documentos totais',
                       'Total de ocorrencias de palavras',
                      'Tamanho do Vocabulario',
                      'Palavras ocorrendo > 1000 vezes',
                       'Palavras ocorrendo uma única vez'
                      ],
              'valor': [len(df), 
                        conta_total_palavras(lista_de_noticias),
                        len(vocabulario),
                        words_more_than(1000, vocabulario),
                        words_ocurring_once(vocabulario)
                       ]
             })
# Out:
#                                info  valor
# 0                 Documentos totais    139
# 1  Total de ocorrencias de palavras  41879
# 2            Tamanho do Vocabulario  11284
# 3   Palavras ocorrendo > 1000 vezes      0
# 4  Palavras ocorrendo uma única vez   6289

# %% [markdown]
# **2 - Refaça a questão 2 do Laboratório anterior usando os tokens produzidos (5 pts). **

# %%
sorted_d = sorted(vocabulario.items(), key=operator.itemgetter(1), reverse = True)
total_palavras = conta_total_palavras(lista_de_noticias)
freq_relativa = [(v/total_palavras) for (k,v) in sorted_d[:50]]


#Calcula o valor da constante 'c' == Pr*r
def get_constants_values(freqs_relativas):
  constants_values = []
  for i in range(len(freqs_relativas)):
    c_value = freqs_relativas[i] * (i+1)
    constants_values.append(c_value)
  return constants_values


pd.DataFrame({
    'word': [k for (k,v) in sorted_d[:50]],
    'freq': [v for (k,v) in sorted_d[:50]],
    'Pr(%)': [round((v/total_palavras)*100, 2) for (k,v) in sorted_d[:50]],
    'Pr.r': get_constants_values(freq_relativa)
    
})
# Out:
#           word  freq  Pr(%)      Pr.r
# 0    bolsonaro   186   0.44  0.004441
# 1       brasil   185   0.44  0.008835
# 2          ser   180   0.43  0.012894
# 3         anos   178   0.43  0.017001
# 4      governo   174   0.42  0.020774
# 5        sobre   129   0.31  0.018482
# 6   presidente   127   0.30  0.021228
# 7         país   123   0.29  0.023496
# 8         lula   114   0.27  0.024499
# 9     política   110   0.26  0.026266
# 10      porque    99   0.24  0.026003
# 11        pode    99   0.24  0.028367
# 12       gente    98   0.23  0.030421
# 13     pessoas    91   0.22  0.030421
# 14       ainda    90   0.21  0.032236
# 15         ter    88   0.21  0.033621
# 16    nacional    88   0.21  0.035722
# 17        hoje    86   0.21  0.036964
# 18     reforma    80   0.19  0.036295
# 19    educação    76   0.18  0.036295
# 20      contra    76   0.18  0.038110
# 21         vai    72   0.17  0.037823
# 22     segundo    71   0.17  0.038993
# 23       disse    70   0.17  0.040116
# 24       fazer    69   0.16  0.041190
# 25     justiça    69   0.16  0.042838
# 26      apenas    67   0.16  0.043196
# 27    trabalho    67   0.16  0.044796
# 28         ano    66   0.16  0.045703
# 29         dia    66   0.16  0.047279
# 30     federal    66   0.16  0.048855
# 31    ditadura    64   0.15  0.048903
# 32         lei    64   0.15  0.050431
# 33    direitos    63   0.15  0.051147
# 34        caso    62   0.15  0.051816
# 35       menos    61   0.15  0.052437
# 36      estado    60   0.14  0.053010
# 37       então    59   0.14  0.053535
# 38       todos    59   0.14  0.054944
# 39      sempre    59   0.14  0.056353
# 40     momento    58   0.14  0.056783
# 41    ministro    58   0.14  0.058168
# 42        jair    58   0.14  0.059553
# 43        além    57   0.14  0.059887
# 44        todo    56   0.13  0.060173
# 45       paulo    56   0.13  0.061511
# 46         diz    55   0.13  0.061725
# 47       maior    54   0.13  0.061893
# 48      social    54   0.13  0.063182
# 49       agora    54   0.13  0.064471

# %% [markdown]
# **3 - Aplique Stemming nos tokens produzidos e encontre 10 exemplos de falsos positivos e 10 exemplos de falsos negativos. Que impacto você acha que falsos positivos e negativos, como esses, teriam no processamento de consultas? Dê exemplos. (5 pts).**

# %% [markdown]
# - **FALSOS POSITIVOS: **
#
# "passeando" e "passado"
#
# "animal" e "animou"
#
# "fala" e "falimos"
#
# "paris" e "parado"
#
# "postos" e "postei"
#
# "frança" e "franco"
#
# "bandeira" e "bandeirante"
#
# "prova" e "provem"
#
# "sei" e "seio"
#
# "apartamento" e	"aparte"
#
# -----
#
# **FALSOS NEGATIVOS**
#
# "presidente" e "presidencia"
#
# "dado" e "daria"
#
# "deu" e "dado"
#
# "daria" e "deu"
#
# "paredes" e "paredão"
#
# "influem" e "influenciar"
#
# "irmã" e "irmãs"
#
# "liderou" e "lidera"
#
# "filmagens" e "filmes"
#
# "duvida" e "duvidoso"
#
# ---
#
# - **O impacto que esses falsos positivos e falsos negativos teriam nas consultas: **
# Os falsos positivos/negativos podem ter algum impacto significante em algumas consultas, mas não de forma a comprometer todo o motor de busca. Por exemplo, sabendo que o algoritmo de *Stemming* utilizado **não foi capaz** de relacionar as palavras **"presidente"** e **"presidencia"**, suponhamos a hipótese que exista uma notícia que inicie da forma: "Presidencia decreta ..."". Se o usuário fizer uma consulta do formato "decreto presidente" (buscando esta notícia), o motor de busca terá uma dificuldade maior em trazer a notícia desejada se constrastarmos com o cenário em que as duas palavras estão relacionadas.

# %%
stemmer = SnowballStemmer("portuguese") # Algortimo PorterStemmer disponibilizado pela lib nltk
tokens = list(freq_palavras(lista_de_noticias).keys()) # Os tokens produzidos, no caso, estamos usando o vocabulario e pegando as chaves (palavras).
stemmed_tokens = [stemmer.stem(token) for token in tokens] # Aplica o algoritmo PorterStemmer aos tokens
dictionary = {}
for i in range(len(stemmed_tokens)):
  if(stemmed_tokens[i] in dictionary.keys()):
    dictionary[stemmed_tokens[i]].append(tokens[i])
  else:
    dictionary[stemmed_tokens[i]] = []
    dictionary[stemmed_tokens[i]].append(tokens[i])
    

  

pd.DataFrame.from_dict(dictionary, orient='index')
# Out:
#                                                          0   \
# prefeit                                            prefeito
# rio                                                     rio
# bisp                                                  bispo
# marcel                                              marcelo
# crivell                                            crivella
# achou                                                 achou
# explic                                           explicação
# obsessã                                            obsessão
# evangél                                         evangélicos
# israel                                               israel
# ram                                                   ramos
# mesm                                                  mesma
# árvor                                                árvore
# jesus                                                 jesus
# jud                                                   judeu
# diss                                                  disse
# entrev                                           entrevista
# jornal                                           jornalista
# inglês                                               inglês
# david                                                 david
# bill                                                 biller
# lig                                                 ligados
# alma                                                   alma
# entã                                                  então
# tá                                                       tá
# muit                                                 muitas
# pesquis                                           pesquisas
# divulg                                           divulgadas
# seman                                                semana
# mostr                                             mostrando
# qued                                                  queda
# aprov                                             aprovação
# bolsonar                                          bolsonaro
# cham                                                 chamou
# atençã                                              atenção
# ipesp                                                ipespe
# procur                                             procurou
# sab                                                   saber
# brasileir                                       brasileiros
# sent                                               sentindo
# nest                                                  neste
# moment                                              momento
# vésp                                               vésperas
# govern                                              governo
# complet                                           completar
# 100                                                     100
# dias                                                   dias
# result                                            resultado
# colun                                                coluna
# mônic                                                mônica
# bergam                                              bergamo
# folh                                                  folha
# maior                                                 maior
# part                                                  parte
# pesso                                               pessoas
# 62                                                       62
# diz                                                     diz
# preocup                                          preocupada
# envergonh                                      envergonhada
# indign                                            indignada
# trist                                                triste
# med                                                    medo
# hoj                                                    hoje
# brasil                                               brasil
# segund                                              segundo
# realiz                                            realizada
# outr                                                 outras
# 33                                                       33
# afirm                                               afirmam
# estar                                                 estar
# esperanc                                       esperançosas
# alegr                                               alegres
# tranquil                                         tranquilas
# ;                                                         ;
# 2                                                         2
# entusiasm                                     entusiasmadas
# apen                                                 apenas
# 1                                                         1
# orgulh                                           orgulhosas
# incluíd                                            incluído
# gost                                               gostaria
# conhec                                             conhecer
# motiv                                               motivos
# gross                                                grosso
# mod                                                    modo
# reproduz                                           reproduz
# proporçã                                          proporção
# terc                                                  terço
# popul                                             população
# otim                                              otimistas
# vot                                                   votou
# eleiçã                                              eleição
# continu                                            continua
# fiel                                                   fiel
# dois                                                   dois
# desalent                                       desalentados
# constitu                                         constituem
# som                                                    soma
# haddad                                               haddad
# anul                                               anularam
# branc                                                branco
# abstiv                                           abstiveram
# oficial                                             oficial
# merc                                                mercado
# reún                                                  reúne
# banc                                                 bancos
# rentist                                           rentistas
# encomend                                        encomendada
# corretor                                          corretora
# xp                                                       xp
# sexta-feir                                      sexta-feira
# popular                                        popularidade
# janeir                                              janeiro
# cá                                                       cá
# índic                                                índice
# caiu                                                   caiu
# 40                                                       40
# 35                                                       35
# institut                                          instituto
# big                                                     big
# dat                                                    data
# contrat                                          contratada
# revist                                              revista
# vej                                                    veja
# períod                                              período
# 12                                                       12
# pont                                                 pontos
# percentu                                        percentuais
# 50                                                       50
# 38                                                       38
# tod                                                   todas
# númer                                               números
# semelh                                          semelhantes
# cerc                                                  cerca
# aind                                                  ainda
# acredit                                            acredita
# atlas                                                 atlas
# polít                                              político
# hav                                                   havia
# president                                        presidente
# 30,5                                                   30,5
# menor                                                 menor
# rejeit                                             rejeitam
# 31,2                                                   31,2
# nenhum                                               nenhum
# tã                                                      tão
# baix                                                 baixos
# primeir                                           primeiros
# após                                                   após
# redemocratiz                               redemocratização
# país                                                   país
# desilud                                         desiludidos
# class                                                classe
# méd                                                   média
# estim                                            estimativa
# calcul                                              calcula
# 15                                                       15
# milhõ                                               milhões
# eleitor                                           eleitores
# deix                                               deixaram
# avali                                               avaliar
# maneir                                              maneira
# posit                                              positiva
# reag                                                 reagir
# fúr                                                   fúria
# despenc                                         despencando
# fez                                                     fez
# ibge                                                   ibge
# aument                                              aumento
# desempreg                                     desempregados
# 13,1                                                   13,1
# vã                                                      vão
# ter                                                     ter
# mud                                                   mudar
# metodolog                                      metodologias
# corr                                               correrão
# risc                                                  risco
# entrar                                               entrar
# list                                                  lista
# negr                                                  negra
# comun                                            comunistas
# engrac                                            engraçado
# inclu                                               incluir
# rol                                                     rol
# maldit                                             malditos
# control                                            controle
# indiret                                            indireto
# itaú                                                   itaú
# nad                                                    nada
# imposs                                           impossível
# nazism                                              nazismo
# esquerd                                            esquerda
# terr                                                  terra
# plan                                                  plana
# únic                                                  única
# boa                                                     boa
# notíc                                               notícia
# dad                                                    dada
# manhã                                                 manhã
# própri                                              próprio
# ministr                                            ministro
# educ                                               educação
# vélez                                                 vélez
# rodriguez                                         rodriguez
# final                                            finalmente
# dev                                                    deve
# ser                                                     ser
# demit                                              demitido
# segunda-feir                                  segunda-feira
# men                                                   menos
# livr                                                 livros
# didát                                             didáticos
# salv                                                 salvos
# colombian                                        colombiano
# doid                                                  doido
# quer                                                 queria
# reescrev                                         reescrever
# histór                                             história
# bom                                                     bom
# vid                                                    vida
# seg                                                   segue
# regional                                           regional
# repúbl                                            república
# comissã                                            comissão
# especial                                           especial
# mort                                                 mortos
# desaparec                                     desaparecidos
# eugên                                               eugênia
# gonzag                                              gonzaga
# dúv                                                  dúvida
# comet                                                comete
# crim                                                  crime
# respons                                    responsabilidade
# improb                                          improbidade
# administr                                    administrativa
# mand                                                 mandar
# quart                                              quartéis
# celebr                                           celebrarem
# 31                                                       31
# marc                                                  março
# iníci                                                início
# ditadur                                            ditadura
# civil-milit                                   civil-militar
# 1964-1985                                         1964-1985
# 55                                                       55
# anos                                                   anos
# destituiçã                                      destituição
# joã                                                    joão
# goulart                                             goulart
# gravidad                                          gravidade
# grand                                                grande
# porqu                                                porque
# fal                                                 falando
# cois                                                  coisa
# juríd                                              jurídica
# sobr                                                  sobre
# legal                                            legalidade
# própr                                               própria
# constituiçã                                    constituição
# 1988                                                   1988
# admit                                               admitiu
# 1964                                                   1964
# golp                                                  golpe
# quis                                                 quiser
# usar                                                   usar
# term                                                  termo
# pod                                                    pode
# ‘                                                         ‘
# quebr                                                quebra
# eleit                                                eleito
# razõ                                                 razões
# derrub                                            derrubado
# segu                                                 seguiu
# process                                            processo
# forc                                                 forças
# contrár                                          contrárias
# simples                                        simplesmente
# assum                                             assumiram
# marilu                                               marilu
# cabañ                                               cabañas
# glauc                                                glauco
# far                                                   faria
# rádi                                                  rádio
# atual                                                 atual
# contraposiçã                                  contraposição
# discurs                                            discurso
# grup                                                  grupo
# tortur                                              tortura
# nunc                                                  nunca
# promov                                             promovem
# doming                                              domingo
# 1ª                                                       1ª
# caminh                                            caminhada
# silênci                                            silêncio
# homenag                                           homenagem
# vítim                                               vítimas
# violênc                                           violência
# cotidian                                          cotidiana
# caus                                                causada
# estad                                                estado
# ato                                                     ato
# acontec                                            acontece
# 16h                                                     16h
# prac                                                  praça
# paz                                                     paz
# parqu                                                parque
# ibirapu                                          ibirapuera
# volt                                                  volta
# 18h                                                     18h
# monument                                          monumento
# localiz                                          localizado
# próxim                                              próximo
# portã                                                portão
# 10                                                       10
# propost                                            proposta
# surg                                                 surgiu
# bah                                                   bahia
# sid                                                    sido
# bem                                                     bem
# receb                                              recebida
# parent                                             parentes
# milit                                            militantes
# direit                                             direitos
# human                                               humanos
# antes                                                 antes
# jair                                                   jair
# psl                                                     psl
# recomend                                         recomendar
# armad                                               armadas
# comemor                                         comemorarem
# recent                                             recentes
# declar                                          declarações
# ganh                                                 ganhou
# comand                                           comandante
# exércit                                            exército
# general                                             general
# edson                                                 edson
# leal                                                   leal
# puj                                                    pujo
# imprens                                            imprensa
# arrepend                                         arrependem
# justific                                         justificam
# razã                                                  razão
# supost                                         supostamente
# perig                                                perigo
# gent                                                  gente
# vermelh                                            vermelho
# superestim                                    superestimado
# pond                                                pondera
# assim                                                 assim
# tent                                                tentava
# reform                                             reformas
# soc                                                 sociais
# inclusiv                                          inclusive
# previst                                           previstas
# vigor                                                 vigor
# époc                                                  época
# 1946                                                   1946
# defensor                                           defensor
# tes                                                    tese
# regim                                                regime
# durant                                              durante
# 21                                                       21
# mat                                                   matou
# persegu                                           perseguiu
# opositor                                         opositores
# membr                                               membros
# ativ                                                  ativa
# reserv                                              reserva
# têm                                                     têm
# vontad                                              vontade
# neg                                                   negar
# consequent                                    consequências
# narrat                                            narrativa
# vez                                                   vezes
# faz                                                   fazer
# crer                                                   crer
# problem                                           problemas
# comec                                               começou
# institucional                                 institucional
# nº                                                       nº
# 5                                                         5
# ai-5                                                   ai-5
# dezembr                                            dezembro
# 1968                                                   1968
# fech                                                 fechou
# congress                                          congresso
# decret                                             decretou
# censur                                              censura
# sustent                                            sustenta
# exempl                                              exemplo
# lembr                                                lembra
# assassinat                                      assassinato
# estud                                             estudante
# luís                                                   luís
# lim                                                    lima
# sout                                                  souto
# promulg                                         promulgação
# 18                                                       18
# tir                                                    tiro
# peit                                                  peito
# dispar                                            disparado
# policial                                           policial
# invad                                               invadiu
# restaur                                         restaurante
# central                                             central
# calabouc                                          calabouço
# onde                                                   onde
# manifest                                       manifestação
# exig                                               exigindo
# melhor                                            melhorias
# estrutur                                          estrutura
# prov                                                  prova
# exist                                                existe
# recrudesc                                       recrudesceu
# adot                                                adotava
# postur                                              postura
# extrem                                         extremamente
# violent                                            violenta
# relaçã                                              relação
# jovens                                               jovens
# armas                                                 armas
# grau                                                   grau
# periculos                                    periculosidade
# diant                                                diante
# agent                                               agentes
# xxxx                                                   xxxx
# 2019                                                   2019
# paláci                                              palácio
# planalt                                            planalto
# distribu                                         distribuiu
# víd                                                   vídeo
# enaltec                                            enaltece
# papel                                                 papel
# reconhec                                          reconhece
# contr                                                contra
# esclarec                                         esclareceu
# propagand                                        propaganda
# ilegal                                               ilegal
# ediçã                                                edição
# broth                                               brother
# 2002                                                   2002
# vi                                                       vi
# episódi                                            episódio
# reality                                             reality
# show                                                   show
# ineg                                               inegável
# program                                            programa
# glob                                                  globo
# tend                                                  tendo
# repercussã                                      repercussão
# jean                                                   jean
# wyllys                                               wyllys
# torn                                                 tornou
# particip                                         participar
# ediçõ                                               edições
# personal                                      personalidade
# levant                                             levantar
# bandeir                                            bandeira
# lgbt                                                   lgbt
# dest                                                  desta
# aren                                                  arena
# rodrig                                              rodrigo
# franc                                                frança
# alto                                                   alto
# rejeiçã                                            rejeição
# 69,7                                                   69,7
# elimin                                            eliminado
# ator                                                   ator
# dramaturg                                        dramaturgo
# fic                                                  ficado
# chat                                               chateado
# cont                                                 contam
# convers                                           conversei
# linchament                                      linchamento
# moral                                                 moral
# famíl                                               família
# sofr                                                sofrido
# red                                                   redes
# mã                                                      mãe
# tom                                                 tomando
# medic                                           medicamento
# xing                                                xingada
# fábi                                                  fábio
# irmã                                                  irmão
# contratu                                        contratuais
# dar                                                     dar
# veícul                                             veículos
# ver                                                    vera
# lúc                                                   lúcia
# ferreir                                            ferreira
# silv                                                  silva
# don                                                    dona
# verinh                                              verinha
# feit                                                  feito
# sucess                                              sucesso
# social                                               social
# funk                                                   funk
# menin                                                menino
# ronc                                                 roncar
# músic                                                música
# respost                                            resposta
# bem-humor                                      bem-humorada
# situaçõ                                           situações
# hostil                                          hostilidade
# enfrent                                           enfrentou
# cas                                                    casa
# ali                                                     ali
# coloc                                              colocado
# dorm                                                 dormir
# lug                                                   lugar
# ofend                                              ofendida
# expressõ                                         expressões
# racist                                             racistas
# depressã                                          depressão
# alívi                                                alívio
# filh                                                  filho
# porém                                                 porém
# grav                                                  grave
# notór                                               notória
# paul                                                  paula
# indic                                             indicaria
# paredã                                              paredão
# mex                                                    mexe
# trech                                               trechos
# oxum                                                   oxum
# lá                                                       lá
# soub                                                  soube
# decisã                                              decisão
# barat                                                barato
# candombl                                          candomblé
# algo                                                   algo
# malign                                              maligno
# pervers                                            perverso
# cuid                                                cuidado
# pergunt                                           perguntar
# ataqu                                                ataque
# pes                                                  pesado
# internaut                                       internautas
# macac                                                macaco
# zoológ                                            zoológico
# defin                                             definiram
# lix                                                    lixo
# sociedad                                          sociedade
# temp                                                 tempos
# atrás                                                 atrás
# trajetór                                         trajetória
# diferenc                                         diferencia
# brothers                                           brothers
# destac                                             destacou
# teatr                                                teatro
# pec                                                   peças
# fort                                                  forte
# conteúd                                            conteúdo
# encen                                               encenou
# pequen                                              pequeno
# príncip                                            príncipe
# advog                                              advogado
# ricard                                              ricardo
# brajterman                                       brajterman
# amig                                                 amigos
# ambos                                                 ambos
# lut                                                   lutam
# parec                                             parecidas
# moviment                                          movimento
# diretor                                             diretor
# feder                                             federação
# israelit                                          israelita
# afast                                               afastou
# polêm                                              polêmico
# hebraic                                            hebraica
# convid                                             convidou
# palestr                                            palestra
# pré-candidat                                  pré-candidato
# cit                                                   citou
# quilomb                                            quilombo
# refer                                               referiu
# morador                                           moradores
# arroub                                              arrouba
# anim                                                animais
# compar                                             comparou
# nasciment                                        nascimento
# fraquej                                          fraquejada
# coraj                                             corajosas
# professor                                         professor
# puc                                                     puc
# aceit                                               aceitou
# desafi                                              desafio
# mov                                                   mover
# açõ                                                   ações
# autor                                               autores
# mensagens                                         mensagens
# pass                                                  passo
# identific                                       identificar
# agressor                                         agressores
# perf                                                 perfis
# fak                                                    fake
# verdadeir                                       verdadeiros
# respond                                         responderão
# atos                                                   atos
# dcm                                                     dcm
# apresent                                         apresentar
# queix                                                queixa
# diret                                           diretamente
# delegac                                           delegacia
# combat                                              combate
# intoler                                        intolerância
# abert                                                aberta
# investig                                       investigação
# contat                                              contato
# certez                                              certeza
# disposiçã                                        disposição
# ir                                                       ir
# fim                                                     fim
# comig                                                comigo
# tip                                                    tipo
# impun                                                impune
# civ                                                   civis
# cobr                                               cobrados
# indeniz                                           indenizar
# preconceit                                      preconceito
# racism                                              racismo
# empoder                                         empoderados
# carát                                               caráter
# pedagóg                                          pedagógico
# enfim                                                 enfim
# serv                                                 servir
# útil                                                   útil
# vá                                                       vá
# além                                                   além
# vitrin                                              vitrine
# busc                                                  busca
# quinz                                                quinze
# minut                                               minutos
# fam                                                    fama
# televisã                                          televisão
# ajud                                                 ajudar
# líd                                                 líderes
# apo                                                  apoiam
# fascism                                            fascismo
# dentr                                                dentre
# 17                                                       17
# mil                                                     mil
# pastor                                             pastores
# alemanh                                            alemanha
# apoi                                                 apoiar
# nazist                                              nazista
# protest                                        protestantes
# ouv                                                 ouviram
# insist                                           insistindo
# cooper                                          cooperassem
# hitl                                                 hitler
# absolut                                            absoluta
# consegu                                          conseguida
# eleiçõ                                             eleições
# estadu                                            estaduais
# 1932                                                   1932
# oldemburg                                        oldemburgo
# distrit                                            distrito
# 75                                                       75
# nacional                                       nacionalismo
# anti-comun                                   anti-comunismo
# ressent                                      ressentimentos
# internacional                                 internacional
# trat                                               tratados
# punit                                             punitivos
# guerr                                                guerra
# mundial                                             mundial
# influenc                                      influenciaram
# decisõ                                             decisões
# catól                                             católicos
# vast                                                  vasta
# eleg                                               elegeram
# luteran                                           luteranos
# batist                                             batistas
# cristã                                             cristãos
# lider                                             liderados
# clérig                                             clérigos
# reverend                                         reverendos
# diácon                                             diáconos
# tolic                                                tolice
# suj                                                   sujas
# sang                                                 sangue
# acord                                                acordo
# cens                                                  censo
# 1934                                                   1934
# realidad                                          realidade
# princip                                          principais
# elogi                                             elogiaram
# desempenh                                        desempenho
# favor                                                 favor
# crianc                                             crianças
# [                                                         [
# ]                                                         ]
# igrej                                               igrejas
# cúmplic                                           cúmplices
# adolf                                                 adolf
# intermédi                                        intermédio
# tornar-s                                          tornar-se
# inglaterr                                        inglaterra
# f                                                         f
# fullbrandt                                       fullbrandt
# ninguém                                             ninguém
# opôs                                                   opôs
# dilúvi                                              dilúvio
# descrenc                                          descrença
# ameac                                              ameaçava
# europ                                                europa
# ocident                                            ocidente
# igual                                                 igual
# apoiador                                         apoiadores
# bwa                                                     bwa
# lid                                                   lidar
# bolchev                                         bolchevismo
# deu                                                     deu
# bel                                                    belo
# observ                                              observe
# john                                                   john
# w                                                         w
# bradbury                                           bradbury
# boston                                               boston
# massachusetts                                 massachusetts
# reuniã                                              reunião
# praz                                                 prazer
# ido                                                     ido
# sex                                                    sexo
# film                                                 filmes
# imor                                                imorais
# assist                                           assistidos
# satisf                                           satisfação
# óbvi                                                  óbvia
# escrev                                             escreveu
# nov                                                    nova
# queim                                               queimou
# montanh                                           montanhas
# corromp                                         corrompidas
# fiz                                                 fizeram
# fogueir                                           fogueiras
# compost                                           compostas
# judeus…                                             judeus…
# mental                                          mentalidade
# sér                                                   séria
# naçõ                                                 nações
# agiss                                               agissem
# seriedad                                          seriedade
# novent                                              noventa
# cent                                                  cento
# viaj                                                 viajei
# cidad                                               cidades
# not                                                    nota
# jazz                                                   jazz
# sequ                                                 sequer
# !                                                         !
# watchman-examin                           watchman-examiner
# xxi                                                    xxii
# 37                                                       37
# ,13                                                     ,13
# setembr                                            setembro
# confessional                                   confessional
# confess                                         confessante
# ...
# singular                             None       None     None
# autorizando-                         None       None     None
# plausibil                            None       None     None
# 26-c                                 None       None     None
# enfoqu                               None       None     None
# efetu                                None       None     None
# originár                             None       None     None
# ângul                                None       None     None
# ótic                                 None       None     None
# advind                               None       None     None
# eiv                                  None       None     None
# superficial                          None       None     None
# proposital                           None       None     None
# inabilitá-l                          None       None     None
# irrevers                             None       None     None
# encurt                               None       None     None
# abster                               None       None     None
# inert                                None       None     None
# meandr                               None       None     None
# dissec                               None       None     None
# propag                               None       None     None
# aberr                                None       None     None
# especula-s                           None       None     None
# 1981                                 None       None     None
# implementá-l                         None       None     None
# andras                               None       None     None
# uthoff                               None       None     None
# mostrou-s                            None       None     None
# poupanc                              None       None     None
# ericsson                             None       None     None
# monstr                               None       None     None
# formaliz                             None       None     None
# robotiz                              None       None     None
# autom                                None       None     None
# empreendedor                         None       None     None
# chilen                               None       None     None
# vitalíc                              None       None     None
# afp                                  None       None     None
# 420                                  None       None     None
# 220                                  None       None     None
# 1000                                 None       None     None
# median                               None       None     None
# embut                                None       None     None
# privileg                             None       None     None
# assev                                None       None     None
# bachelet                             None       None     None
# preocupando-s                        None       None     None
# demográf                             None       None     None
# adapt                                None       None     None
# sud                                  None       None     None
# neutr                                None       None     None
# miguel                               None       None     None
# nagib                                None       None     None
# mordac                               None       None     None
# russel                               None       None     None
# dutr                                 None       None     None
# aprendizag                           None       None     None
# discutia-s                           None       None     None
# apens                                None       None     None
# temát                                None       None     None
# legislatur                           None       None     None
# ms                                   None       None     None
# picu                                 None       None     None
# pb                                   None       None     None
# meimendr                             None       None     None
# marian                               None       None     None
# schneid                              None       None     None
# exacerb                              None       None     None
# intimid                              None       None     None
# lourenc                              None       None     None
# rs                                   None       None     None
# visibil                              None       None     None
# promoçã                              None       None     None
# étnico-racial                        None       None     None
# 2008                                 None       None     None
# distorc                              None       None     None
# amostrag                             None       None     None
# achav                                None       None     None
# tens                                 None       None     None
# can                                  None       None     None
# inexpress                            None       None     None
# exemplific                           None       None     None
# maranhã                              None       None     None
# flavi                                None       None     None
# din                                  None       None     None
# aprendiz                             None       None     None
# pls                                  None       None     None
# leopold                              None       None     None
# cidadãs                              None       None     None
# esfacel                              None       None     None
# atuaçõ                               None       None     None
# deputados…                           None       None     None
# format                               None       None     None
# íam                                  None       None     None
# estatut                              None       None     None
# étnico-rac                           None       None     None
# flavinh                              None       None     None
# entrass                              None       None     None
# proponent                            None       None     None
# substitut                            None       None     None
# proposiçõ                            None       None     None
# érik                                 None       None     None
# koka                                 None       None     None
# compus                               None       None     None
# atuant                               None       None     None
# particular                           None       None     None
# desol                                None       None     None
# estági                               None       None     None
# adoec                                None       None     None
# deprim                               None       None     None
# indiferent                           None       None     None
# esvazi                               None       None     None
# bagag                                None       None     None
# evasã                                None       None     None
# tutelares…                           None       None     None
# planejamento…                        None       None     None
# crônic                               None       None     None
# desestrutur                          None       None     None
# inconstitucion                       None       None     None
# penetr                               None       None     None
# tec                                  None       None     None
# caos                                 None       None     None
# gênero…                              None       None     None
# oficin                               None       None     None
# capoeir                              None       None     None
# percussã                             None       None     None
# matriz                               None       None     None
# african                              None       None     None
# auto-censur                          None       None     None
# filmagens                            None       None     None
# proíb                                None       None     None
# acusando-                            None       None     None
# crítica…                             None       None     None
# hegemôn                              None       None     None
# contrapont                           None       None     None
# frequênc                             None       None     None
# resolu                               None       None     None
# laz                                  None       None     None
# cultura…                             None       None     None
# cald                                 None       None     None
# nota-s                               None       None     None
# abarc                                None       None     None
# saúde…                               None       None     None
# problemát                            None       None     None
# padroniz                             None       None     None
# vindour                              None       None     None
# globoplay                            None       None     None
# streaming                            None       None     None
# telespect                            None       None     None
# ferr                                 None       None     None
# shipp                                None       None     None
# estrel                               None       None     None
# aruan                                None       None     None
# taís                                 None       None     None
# falabell                             None       None     None
# leandr                               None       None     None
# thain                                None       None     None
# duart                                None       None     None
# encost                               None       None     None
# netflix                              None       None     None
# diretor-geral                        None       None     None
# mesquit                              None       None     None
# assets                               None       None     None
# the                                  None       None     None
# good                                 None       None     None
# doctor                               None       None     None
# ex-méd                               None       None     None
# rog                                  None       None     None
# abdelmassih                          None       None     None
# cauã                                 None       None     None
# reymond                              None       None     None
# casadevall                           None       None     None
# carro-chef                           None       None     None
# rivaliz                              None       None     None
# alard                                None       None     None
# telejornal                           None       None     None
# favorit                              None       None     None
# catálog                              None       None     None
# promocional                          None       None     None
# boechat                              None       None     None
# interval                             None       None     None
# brav                                 None       None     None
# areth                                None       None     None
# franklin                             None       None     None
# medeir                               None       None     None
# achômetr                             None       None     None
# opiniômetr                           None       None     None
# afiadíssim                           None       None     None
# venenômetr                           None       None     None
# abastec                              None       None     None
# ex-atriz                             None       None     None
# giovann                              None       None     None
# ewbank                               None       None     None
# hj                                   None       None     None
# chapulet                             None       None     None
# brun                                 None       None     None
# fif                                  None       None     None
# gagliass                             None       None     None
# empiricus                            None       None     None
# marketing                            None       None     None
# client                               None       None     None
# lasc                                 None       None     None
# bettin                               None       None     None
# 1520                                 None       None     None
# ton                                  None       None     None
# tutorial                             None       None     None
# cocaín                               None       None     None
# newslett                             None       None     None
# ceo                                  None       None     None
# link                                 None       None     None
# preâmbul                             None       None     None
# comprometedor                        None       None     None
# ,est                                 None       None     None
# cach                                 None       None     None
# reminiscent                          None       None     None
# ,fic                                 None       None     None
# escarcéu                             None       None     None
# notinh                               None       None     None
# maldos                               None       None     None
# antagon                              None       None     None
# sintoniz                             None       None     None
# escamot                              None       None     None
# reciproc                             None       None     None
# sam                                  None       None     None
# lanchonet                            None       None     None
# popey                                None       None     None
# humildad                             None       None     None
# atendent                             None       None     None
# zero-três                            None       None     None
# samb                                 None       None     None
# caipirinh                            None       None     None
# estudi                               None       None     None
# abestalh                             None       None     None
# expertis                             None       None     None
# boff                                 None       None     None
# triunf                               None       None     None
# estupidez                            None       None     None
# suponh                               None       None     None
# aperfeiço                            None       None     None
# idiom                                None       None     None
# auxili                               None       None     None
# ,se                                  None       None     None
# possuí                               None       None     None
# temporari                            None       None     None
# inibidor                             None       None     None
# entrepreneurship                     None       None     None
# think-tank                           None       None     None
# tupi-guaran                          None       None     None
# 432                                  None       None     None
#
# [6761 rows x 20 columns]

# %% [markdown]
# **4 - Refaça a questão 3 do Laboratório anterior usando os tokens stemizados. Você percebeu alguma diferença em relação aos tokens sem stemming? Se sim, quais? (10 pts.)**

# %%
freq = [v for (k,v) in sorted_d] # Lista de frequencias
ranking_list = [x+1 for x in range(len(freq))]
pyplot.plot(ranking_list, freq)
pyplot.xscale('log')
pyplot.yscale('log')
pyplot.xlabel('ranking')
pyplot.ylabel('freq')
# Out:
# Text(0, 0.5, 'freq')
